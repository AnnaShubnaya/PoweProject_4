# %%
begin
    using Pkg
    Pkgs = ["CSV", "DataFrames", "Ipopt", "JuMP", "PowerModels"]
    for p in Pkgs
        if Base.find_package(p) == nothing
            Pkg.add(p)
        end
    end
    using CSV, DataFrames, Ipopt, JuMP, PowerModels
end

# %%
m200math, m200phys, m120math, m120phys = CSV.read("Model#2_1_year_200KWh.csv", DataFrame), CSV.read("ml_200kwh.csv", DataFrame), 
    CSV.read("Model#2_1_year_120KWh.csv", DataFrame),CSV.read("ml_120kwh.csv", DataFrame)

m120math
# Out:
# 8640×9 DataFrame
#   Row │ P2       P1       E        Pch      Pdis     Demand   Emax     SolarGe ⋯
#       │ Float64  Float64  Float64  Float64  Float64  Float64  Float64  Float64 ⋯
# ──────┼─────────────────────────────────────────────────────────────────────────
#     1 │    1.71    18.51    10.0      0.0      0.0     20.22   120.0       0.0 ⋯
#     2 │    1.47    17.61    10.0      0.0      0.0     19.08   120.0       0.0
#     3 │    1.71    16.6     10.0      0.0      0.0     18.31   120.0       0.0
#     4 │    1.65    15.9     10.0      0.0      0.0     17.55   120.0       0.0
#     5 │    1.66    15.89    10.0      0.0      0.0     17.55   120.0       0.0 ⋯
#     6 │    1.66    15.89    10.0      0.0      0.0     17.55   120.0       0.0
#     7 │    1.72    18.88    10.0      0.0      0.0     20.6    120.0       0.0
#     8 │    1.74    19.71    10.0      0.0      0.0     22.89   120.0       1.4
#     9 │    1.6     12.58    10.0      0.0      0.0     26.24   120.0      12.0 ⋯
#    10 │    1.15     1.3     10.0      0.0      0.0     27.47   120.0      25.0
#    11 │    0.0      0.0     10.0      9.05     0.0     27.85   120.0      36.9
#   ⋮   │    ⋮        ⋮        ⋮        ⋮        ⋮        ⋮        ⋮        ⋮    ⋱
#  8631 │    0.0      0.0     71.6     25.3      0.0     25.94   118.93     51.2
#  8632 │    0.0      0.0     93.45    19.34     0.0     25.18   118.93     44.5 ⋯
#  8633 │    0.0      0.0    109.48     9.7      0.0     24.8    118.93     34.5
#  8634 │    0.61     0.63   118.93     0.0      1.79    25.18   118.93     22.1
#  8635 │    1.78     1.3    117.1      0.0     18.78    31.28   118.93      9.4
#  8636 │    2.02     6.96    97.83     0.0     28.81    38.15   118.93      0.3 ⋯
#  8637 │    1.91    14.79    68.28     0.0     20.3     37.01   118.93      0.0
#  8638 │    1.86    17.42    47.45     0.0     13.52    32.81   118.93      0.0
#  8639 │    1.8     17.96    33.58     0.0      8.09    27.85   118.93      0.0
#  8640 │    1.73    16.29    25.29     0.0      4.87    22.89   118.93      0.0 ⋯
#                                                  2 columns and 8619 rows omitted

# %%
using Plots
plot(m200math[!,:Emax] / 200 * 100, label="Computational model, capacity = 200 kW*h", 
    title = "1-year battery degradation", xlabel = "Time, h", ylabel="Battery capacity, %",
    )
plot!(m200phys[!, "Capacity, %"], label ="Simulation results, capacity = 200 kW*h")
plot!(m120math[!,:Emax] / 120 * 100, label="Computational model, capacity = 120 kW*h")
plot!(m120phys[!, "Capacity, %"], label ="Simulation results, capacity = 120 kW*h")


#plot!(sqrt.(ws_LP), label="LP")
#plot!(xlabel="Bus number", ylabel=L"V")
#plot!(title="Voltage magnitude profile")
# Out:
# MethodError: no method matching isless(::Float64, ::StepRange{Int64, Int64})
# Closest candidates are:
#   isless(::AbstractFloat, ::ForwardDiff.Dual{Ty, V, N} where {V, N}) where Ty at /home/anna897/.julia/packages/ForwardDiff/tZ5o1/src/dual.jl:145
#   isless(::AbstractFloat, ::Union{StatsBase.PValue, StatsBase.TestStat}) at /home/anna897/.julia/packages/StatsBase/CuCbN/src/statmodels.jl:524
#   isless(::Real, ::AbstractGray{T} where T) at /home/anna897/.julia/packages/ColorTypes/6m8P7/src/operations.jl:32
#   ...
#
# Stacktrace:
#   [1] <(x::Float64, y::StepRange{Int64, Int64})
#     @ Base ./operators.jl:279
#   [2] <=(x::Float64, y::StepRange{Int64, Int64})
#     @ Base ./operators.jl:328
#   [3] (::Plots.var"#107#109"{Float64, Float64})(t::StepRange{Int64, Int64})
#     @ Plots ~/.julia/packages/Plots/LSKOd/src/axes.jl:191
#   [4] filter(f::Plots.var"#107#109"{Float64, Float64}, a::Vector{StepRange{Int64, Int64}})
#     @ Base ./array.jl:2511
#   [5] optimal_ticks_and_labels(ticks::Vector{StepRange{Int64, Int64}}, alims::Tuple{Float64, Float64}, scale::Symbol, formatter::Symbol)
#     @ Plots ~/.julia/packages/Plots/LSKOd/src/axes.jl:191
#   [6] get_ticks(::Vector{StepRange{Int64, Int64}}, ::Vector{Float64}, ::Vector{Any}, ::Tuple{Float64, Float64}, ::Vararg{Any, N} where N)
#     @ Plots ~/.julia/packages/Plots/LSKOd/src/axes.jl:323
#   [7] get_ticks(sp::Plots.Subplot{Plots.GRBackend}, axis::Plots.Axis; update::Bool)
#     @ Plots ~/.julia/packages/Plots/LSKOd/src/axes.jl:241
#   [8] get_ticks
#     @ ~/.julia/packages/Plots/LSKOd/src/axes.jl:224 [inlined]
#   [9] _update_min_padding!(sp::Plots.Subplot{Plots.GRBackend})
#     @ Plots ~/.julia/packages/Plots/LSKOd/src/backends/gr.jl:887
#  [10] iterate
#     @ ./generator.jl:47 [inlined]
#  [11] _collect(c::Matrix{AbstractLayout}, itr::Base.Generator{Matrix{AbstractLayout}, typeof(Plots._update_min_padding!)}, #unused#::Base.EltypeUnknown, isz::Base.HasShape{2})
#     @ Base ./array.jl:695
#  [12] collect_similar
#     @ ./array.jl:606 [inlined]
#  [13] map
#     @ ./abstractarray.jl:2294 [inlined]
#  [14] _update_min_padding!(layout::Plots.GridLayout)
#     @ Plots ~/.julia/packages/Plots/LSKOd/src/layouts.jl:287
#  [15] prepare_output(plt::Plots.Plot{Plots.GRBackend})
#     @ Plots ~/.julia/packages/Plots/LSKOd/src/plot.jl:224
#  [16] show(io::IOBuffer, m::MIME{Symbol("image/svg+xml")}, plt::Plots.Plot{Plots.GRBackend})
#     @ Plots ~/.julia/packages/Plots/LSKOd/src/output.jl:212
#  [17] sprint(::Function, ::MIME{Symbol("image/svg+xml")}, ::Vararg{Any, N} where N; context::Nothing, sizehint::Int64)
#     @ Base ./strings/io.jl:105
#  [18] sprint
#     @ ./strings/io.jl:101 [inlined]
#  [19] _ijulia_display_dict(plt::Plots.Plot{Plots.GRBackend})
#     @ Plots ~/.julia/packages/Plots/LSKOd/src/ijulia.jl:47
#  [20] display_dict(plt::Plots.Plot{Plots.GRBackend})
#     @ Plots ~/.julia/packages/Plots/LSKOd/src/init.jl:93
#  [21] #invokelatest#2
#     @ ./essentials.jl:708 [inlined]
#  [22] invokelatest
#     @ ./essentials.jl:706 [inlined]
#  [23] execute_request(socket::ZMQ.Socket, msg::IJulia.Msg)
#     @ IJulia ~/.julia/packages/IJulia/e8kqU/src/execute_request.jl:112
#  [24] #invokelatest#2
#     @ ./essentials.jl:708 [inlined]
#  [25] invokelatest
#     @ ./essentials.jl:706 [inlined]
#  [26] eventloop(socket::ZMQ.Socket)
#     @ IJulia ~/.julia/packages/IJulia/e8kqU/src/eventloop.jl:8
#  [27] (::IJulia.var"#15#18")()
#     @ IJulia ./task.jl:411
